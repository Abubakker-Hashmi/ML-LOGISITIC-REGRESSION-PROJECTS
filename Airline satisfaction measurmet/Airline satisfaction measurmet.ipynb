# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
Airline=pd.read_csv('Invistico_Airline.csv')
Airline.drop(['Customer Type','Type of Travel'],axis=1,inplace=True)

# %%
Airline
# Out:
#         satisfaction  Age     Class  Flight Distance  Seat comfort  \
# 0          satisfied   65       Eco              265             0
# 1          satisfied   47  Business             2464             0
# 2          satisfied   15       Eco             2138             0
# 3          satisfied   60       Eco              623             0
# 4          satisfied   70       Eco              354             0
# ...              ...  ...       ...              ...           ...
# 129875     satisfied   29       Eco             1731             5
# 129876  dissatisfied   63  Business             2087             2
# 129877  dissatisfied   69       Eco             2320             3
# 129878  dissatisfied   66       Eco             2450             3
# 129879  dissatisfied   38       Eco             4307             3
#
#         Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                       0               0              2
# ...

# %%
sns.heatmap(Airline.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
mean_value = Airline['Arrival Delay in Minutes'].mean()
Airline['Arrival Delay in Minutes'].fillna(value=mean_value, inplace=True)

# %%
Airline.columns
# Out:
# Index(['satisfaction', 'Age', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
#Airline['satisfaction']=pd.get_dummies(Airline['satisfaction'],drop_first=True)
#Airline['Class']=pd.get_dummies(Airline['Class'],drop_first=True)

# %%
Airline['Class'].unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
class_mapping = {'Eco': 1, 'Eco Plus': 2, 'Business': 3}
Airline['Class'] = Airline['Class'].replace(class_mapping)

# %%
sns.barplot(y='satisfaction',x='Class',data=Airline)
# Out:
# <Axes: xlabel='Class', ylabel='satisfaction'>

# %%
Airline
# Out:
#         satisfaction  Age  Class  Flight Distance  Seat comfort  \
# 0               True   65      1              265             0
# 1               True   47      3             2464             0
# 2               True   15      1             2138             0
# 3               True   60      1              623             0
# 4               True   70      1              354             0
# ...              ...  ...    ...              ...           ...
# 129875          True   29      1             1731             5
# 129876         False   63      3             2087             2
# 129877         False   69      1             2320             3
# 129878         False   66      1             2450             3
# 129879         False   38      1             4307             3
#
#         Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                       0               0              2
# ...

# %%
Airline['Class'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
sns.pairplot(Airline)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(Airline.drop('satisfaction',axis=1), 
                                                    Airline['satisfaction'], test_size=0.40, 
                                                    random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Create a pipeline with scaling and logistic regression
ml = make_pipeline(StandardScaler(), LogisticRegression())

# %%
ml.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
y_pred=ml.predict(X_test)
len(y_pred)
# Out:
# 51952

# %%
y_pred
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
#Now checking accuracy of our model

# %%
plt.scatter(y_test,y_pred)

# %%
sns.distplot(y_pred)
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_12276\1897921534.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred)
# <Axes: ylabel='Density'>

# %%
sns.distplot(y_test)
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_12276\2957397977.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test)
# <Axes: xlabel='satisfaction', ylabel='Density'>

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.80      0.80     23464
#         True       0.83      0.83      0.83     28488
#
#     accuracy                           0.82     51952
#    macro avg       0.81      0.81      0.81     51952
# weighted avg       0.82      0.82      0.82     51952

# %%
cf=confusion_matrix(y_test,y_pred)
cf
# Out:
# array([[18744,  4888],
#        [ 4720, 23600]], dtype=int64)

# %%
accuracy = ml.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8150600554357869
